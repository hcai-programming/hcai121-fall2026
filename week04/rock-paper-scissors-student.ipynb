# %% [markdown]
# <a target="_blank" rel="noopener noreferrer" href="https://colab.research.google.com/github/hcai-programming/hcai121-fall2026/blob/main/week04/rock-paper-scissors-student.ipynb">![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)</a>

# %% [markdown]
# # Rock, Paper, Scissors
#
# **First:** go to *File → Save a copy in Drive* so you have your own copy to work in.
#
# Everything below already works **except one function** — `winner()`. Your job is to write it. Run the cells top to bottom as you go.

# %% [markdown]
# ## Step 1: Run the scaffold
#
# This sets up the moves and a `play()` function that runs one round. Just run it — you don't need to change anything here.

# %%
import random

def random_move():
    """
    Returns a random move for the computer in a rock-paper-scissors game.
    """

    n = random.randint(1, 3)
    if n == 1:
        return "rock"
    elif n == 2:
        return "paper"
    else:
        return "scissors"

def play(player):
    """
    Plays a round of rock-paper-scissors with the player.
    """
    computer = random_move()
    print("You chose:     ", player)
    print("Computer chose:", computer)

    result = winner(player, computer)
    if result == "tie":
        print("It's a tie!")
    elif result == "player":
        print("You win!")
    else:
        print("Computer wins!")

# %% [markdown]
# ## Step 2: Write `winner()`
#
# Write a function `winner(player, computer)` that returns one of the strings `"tie"`, `"player"`, or `"computer"`.
#
# Think about the cases:
#
# - If both chose the same move, it's a `"tie"`.
# - The **player** wins in exactly three situations:
#   - rock beats scissors
#   - paper beats rock
#   - scissors beats paper
# - Otherwise, the **computer** wins.

# %%
def winner(player, computer):
    # your code here
    pass

# %% [markdown]
# ## Step 3: Test your function
#
# Before running, **predict** what each of these should be. Then run and check.

# %%
print(winner("rock", "scissors"))   # should be: player
print(winner("paper", "rock"))      # should be: player
print(winner("scissors", "rock"))   # should be: computer
print(winner("paper", "paper"))     # should be: tie

# %% [markdown]
# Once those all look right, play a full round:

# %%
play("rock")     # run it a few times — the computer's move changes

# %% [markdown]
# ## Step 4: Share your `winner()`
#
# When your function works, we'll compare everyone's. Copy your `winner()` function into the class gallery notebook so we can look at the differen't approaches together.
#
# **Finished early?** Try one of these:
# - Handle messy input: what if someone types `"Rock"` or `"lizard"`?
# - Print *why* someone won ("rock smashes scissors!").
