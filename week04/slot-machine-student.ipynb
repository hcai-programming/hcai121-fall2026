# %% [markdown]
# <a target="_blank" rel="noopener noreferrer" href="https://colab.research.google.com/github/hcai-programming/hcai121-fall2026/blob/main/week04/slot-machine-student.ipynb">![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)</a>

# %% [markdown]
# # Slot Machine
#
# **First:** go to *File → Save a copy in Drive* so you have your own copy.
#
# The machine spins three reels (numbers 1–5). You decide whether it's a win. Everything works **except one function** `result()`. Your job is to write it.

# %% [markdown]
# ## Step 1: Run the scaffold
#
# This spins the reels and prints the outcome. You don't need to change anything here.

# %%
import random

def play():
    a = random.randint(1, 5)
    b = random.randint(1, 5)
    c = random.randint(1, 5)
    print("   [", a, "|", b, "|", c, "]")

    outcome = result(a, b, c)
    if outcome == "jackpot":
        print("   JACKPOT!")
    elif outcome == "small":
        print("   Small win!")
    else:
        print("   You lose. Spin again!")

# %% [markdown]
# ## Step 2: Write `result()`  —  your turn!
#
# Write a function `result(a, b, c)` that looks at the three reels and returns **one** of these strings:
#
# - `"jackpot"` if **all three** reels match
# - `"small"` if **exactly two** reels match
# - `"lose"` if **none** match

# %%
def result(a, b, c):
    # your code here
    pass

# %% [markdown]
# ## Step 3: Test your function
#
# Before running, **predict** each answer. Then run and check against the comments.

# %%
print(result(3, 3, 3))   # should be: jackpot
print(result(2, 2, 5))   # should be: small
print(result(5, 2, 2))   # should be: small
print(result(2, 5, 2))   # should be: small
print(result(1, 2, 3))   # should be: lose

# %% [markdown]
# Once those all look right, pull the lever:

# %%
play()     # run it a bunch — how long until a jackpot?

# %% [markdown]
# ## Finished early?
#
# - Make the payout depend on the win: print how many coins you won (jackpot = 100, small = 10).
# - Give a **bigger** jackpot when all three reels are `7`.
# - Turn the numbers into symbols (1 = cherry, 2 = bell, …) using more conditionals.
